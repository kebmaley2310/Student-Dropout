# %%
import pandas as pd  
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"c:\Users\USR\Documents\RSEARCH\student dropout.csv")

# %%
df.head()
# Out:
#   School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0     GP      F   18       U         GT3               A                 4
# 1     GP      F   17       U         GT3               T                 1
# 2     GP      F   15       U         LE3               T                 1
# 3     GP      F   15       U         GT3               T                 4
# 4     GP      F   16       U         GT3               T                 3
#
#    Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 0                 4    at_home    teacher  ...         3         4
# 1                 1    at_home      other  ...         3         3
# 2                 1    at_home      other  ...         3         2
# 3                 2     health   services  ...         2         2
# 4                 3      other      other  ...         3         2
#
#    Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   School                       649 non-null    object
#  1   Gender                       649 non-null    object
#  2   Age                          649 non-null    int64
#  3   Address                      649 non-null    object
#  4   Family_Size                  649 non-null    object
#  5   Parental_Status              649 non-null    object
#  6   Mother_Education             649 non-null    int64
#  7   Father_Education             649 non-null    int64
#  8   Mother_Job                   649 non-null    object
#  9   Father_Job                   649 non-null    object
#  10  Reason_for_Choosing_School   649 non-null    object
#  11  Guardian                     649 non-null    object
#  12  Travel_Time                  649 non-null    int64
# ...

# %%
df.describe()
# Out:
#               Age  Mother_Education  Father_Education  Travel_Time  \
# count  649.000000        649.000000        649.000000   649.000000
# mean    16.744222          2.514638          2.306626     1.568567
# std      1.218138          1.134552          1.099931     0.748660
# min     15.000000          0.000000          0.000000     1.000000
# 25%     16.000000          2.000000          1.000000     1.000000
# 50%     17.000000          2.000000          2.000000     1.000000
# 75%     18.000000          4.000000          3.000000     2.000000
# max     22.000000          4.000000          4.000000     4.000000
#
#        Study_Time  Number_of_Failures  Family_Relationship   Free_Time  \
# count  649.000000          649.000000           649.000000  649.000000
# mean     1.930663            0.221880             3.930663    3.180277
# std      0.829510            0.593235             0.955717    1.051093
# min      1.000000            0.000000             1.000000    1.000000
# ...

# %%
df.value_counts()
# Out:
# School  Gender  Age  Address  Family_Size  Parental_Status  Mother_Education  Father_Education  Mother_Job  Father_Job  Reason_for_Choosing_School  Guardian  Travel_Time  Study_Time  Number_of_Failures  School_Support  Family_Support  Extra_Paid_Class  Extra_Curricular_Activities  Attended_Nursery  Wants_Higher_Education  Internet_Access  In_Relationship  Family_Relationship  Free_Time  Going_Out  Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  Number_of_Absences  Grade_1  Grade_2  Final_Grade  Dropped_Out
# ...

# %%
df.groupby("Age").value_counts()
# Out:
# Age  School  Gender  Address  Family_Size  Parental_Status  Mother_Education  Father_Education  Mother_Job  Father_Job  Reason_for_Choosing_School  Guardian  Travel_Time  Study_Time  Number_of_Failures  School_Support  Family_Support  Extra_Paid_Class  Extra_Curricular_Activities  Attended_Nursery  Wants_Higher_Education  Internet_Access  In_Relationship  Family_Relationship  Free_Time  Going_Out  Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  Number_of_Absences  Grade_1  Grade_2  Final_Grade  Dropped_Out
# ...

# %%
df.groupby("School").max()
# Out:
#        Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# School
# GP          M   22       U         LE3               T                 4
# MS          M   20       U         LE3               T                 4
#
#         Father_Education Mother_Job Father_Job Reason_for_Choosing_School  \
# School
# GP                     4    teacher    teacher                 reputation
# MS                     4    teacher    teacher                 reputation
#
#         ... Free_Time  Going_Out  Weekend_Alcohol_Consumption  \
# School  ...
# GP      ...         5          5                            5
# MS      ...         5          5                            5
#
#         Weekday_Alcohol_Consumption Health_Status Number_of_Absences Grade_1  \
# School
# GP                                5             5                 32      18
# MS                                5             5                 12      19
#
#        Grade_2 Final_Grade Dropped_Out
# School
# ...

# %%
df.sort_index()
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0       GP      F   18       U         GT3               A                 4
# 1       GP      F   17       U         GT3               T                 1
# 2       GP      F   15       U         LE3               T                 1
# 3       GP      F   15       U         GT3               T                 4
# 4       GP      F   16       U         GT3               T                 3
# ..     ...    ...  ...     ...         ...             ...               ...
# 644     MS      F   19       R         GT3               T                 2
# 645     MS      F   18       U         LE3               T                 3
# 646     MS      F   18       U         GT3               T                 1
# 647     MS      M   17       U         LE3               T                 3
# 648     MS      M   18       R         LE3               T                 3
#
# ...

# %%
df.set_index("Final_Grade")
# Out:
#             School Gender  Age Address Family_Size Parental_Status  \
# Final_Grade
# 11              GP      F   18       U         GT3               A
# 11              GP      F   17       U         GT3               T
# 12              GP      F   15       U         LE3               T
# 14              GP      F   15       U         GT3               T
# 13              GP      F   16       U         GT3               T
# ...            ...    ...  ...     ...         ...             ...
# 10              MS      F   19       R         GT3               T
# 16              MS      F   18       U         LE3               T
# 9               MS      F   18       U         GT3               T
# 10              MS      M   17       U         LE3               T
# 11              MS      M   18       R         LE3               T
#
#              Mother_Education  Father_Education Mother_Job Father_Job  ...  \
# ...

# %%
df.set_index("Final_Grade").sum()
# Out:
# School                         GPGPGPGPGPGPGPGPGPGPGPGPGPGPGPGPGPGPGPGPGPGPGP...
# Gender                         FFFFFMMFMMFFMMMFFFMMMMMMFFMMMMMMMMMFMMFFFMMMFF...
# Age                                                                        10867
# Address                        UUUUUUUUUUUUUUUUUUUUUUUURUUUUUUURUUUURRRUUUUUU...
# Family_Size                    GT3GT3LE3GT3GT3LE3LE3GT3LE3GT3GT3GT3LE3GT3GT3G...
# Parental_Status                ATTTTTTAATTTTTATTTTTTTTTTTTTATTTTTTTTATTTTTTTA...
# Mother_Education                                                            1632
# Father_Education                                                            1497
# Mother_Job                     at_homeat_homeat_homehealthotherservicesothero...
# Father_Job                     teacherotherotherservicesotherotherotherteache...
# Reason_for_Choosing_School     coursecourseotherhomehomereputationhomehomehom...
# Guardian                       motherfathermothermotherfathermothermothermoth...
# ...

# %%
df.sort_values("Dropped_Out").max()
# Out:
# School                                 MS
# Gender                                  M
# Age                                    22
# Address                                 U
# Family_Size                           LE3
# Parental_Status                         T
# Mother_Education                        4
# Father_Education                        4
# Mother_Job                        teacher
# Father_Job                        teacher
# Reason_for_Choosing_School     reputation
# Guardian                            other
# Travel_Time                             4
# Study_Time                              4
# Number_of_Failures                      3
# School_Support                        yes
# Family_Support                        yes
# Extra_Paid_Class                      yes
# Extra_Curricular_Activities           yes
# Attended_Nursery                      yes
# Wants_Higher_Education                yes
# Internet_Access                       yes
# ...

# %%
df
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0       GP      F   18       U         GT3               A                 4
# 1       GP      F   17       U         GT3               T                 1
# 2       GP      F   15       U         LE3               T                 1
# 3       GP      F   15       U         GT3               T                 4
# 4       GP      F   16       U         GT3               T                 3
# ..     ...    ...  ...     ...         ...             ...               ...
# 644     MS      F   19       R         GT3               T                 2
# 645     MS      F   18       U         LE3               T                 3
# 646     MS      F   18       U         GT3               T                 1
# 647     MS      M   17       U         LE3               T                 3
# 648     MS      M   18       R         LE3               T                 3
#
# ...

# %%
rows, columns = df.shape
rows
# Out:
# 649

# %%
rows, columns = df.shape
columns
# Out:
# 34

# %%
df.tail()
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 644     MS      F   19       R         GT3               T                 2
# 645     MS      F   18       U         LE3               T                 3
# 646     MS      F   18       U         GT3               T                 1
# 647     MS      M   17       U         LE3               T                 3
# 648     MS      M   18       R         LE3               T                 3
#
#      Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 644                 3   services      other  ...         4         2
# 645                 1    teacher   services  ...         3         4
# 646                 1      other      other  ...         1         1
# 647                 1   services   services  ...         4         5
# 648                 2   services      other  ...         4         1
#
#      Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  \
# ...

# %%
df.head()
# Out:
#   School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0     GP      F   18       U         GT3               A                 4
# 1     GP      F   17       U         GT3               T                 1
# 2     GP      F   15       U         LE3               T                 1
# 3     GP      F   15       U         GT3               T                 4
# 4     GP      F   16       U         GT3               T                 3
#
#    Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 0                 4    at_home    teacher  ...         3         4
# 1                 1    at_home      other  ...         3         3
# 2                 1    at_home      other  ...         3         2
# 3                 2     health   services  ...         2         2
# 4                 3      other      other  ...         3         2
#
#    Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  \
# ...

# %%
df.tail(1)
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 648     MS      M   18       R         LE3               T                 3
#
#      Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 648                 2   services      other  ...         4         1
#
#      Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  \
# 648                            3                            4              5
#
#     Number_of_Absences Grade_1 Grade_2 Final_Grade Dropped_Out
# 648                  4      10      11          11       False
#
# [1 rows x 34 columns]

# %%
df.max
# Out:
# <bound method DataFrame.max of     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0       GP      F   18       U         GT3               A                 4
# 1       GP      F   17       U         GT3               T                 1
# 2       GP      F   15       U         LE3               T                 1
# 3       GP      F   15       U         GT3               T                 4
# 4       GP      F   16       U         GT3               T                 3
# ..     ...    ...  ...     ...         ...             ...               ...
# 644     MS      F   19       R         GT3               T                 2
# 645     MS      F   18       U         LE3               T                 3
# 646     MS      F   18       U         GT3               T                 1
# 647     MS      M   17       U         LE3               T                 3
# 648     MS      M   18       R         LE3               T                 3
#
# ...

# %%
df.columns
# Out:
# Index(['School', 'Gender', 'Age', 'Address', 'Family_Size', 'Parental_Status',
#        'Mother_Education', 'Father_Education', 'Mother_Job', 'Father_Job',
#        'Reason_for_Choosing_School', 'Guardian', 'Travel_Time', 'Study_Time',
#        'Number_of_Failures', 'School_Support', 'Family_Support',
#        'Extra_Paid_Class', 'Extra_Curricular_Activities', 'Attended_Nursery',
#        'Wants_Higher_Education', 'Internet_Access', 'In_Relationship',
#        'Family_Relationship', 'Free_Time', 'Going_Out',
#        'Weekend_Alcohol_Consumption', 'Weekday_Alcohol_Consumption',
#        'Health_Status', 'Number_of_Absences', 'Grade_1', 'Grade_2',
#        'Final_Grade', 'Dropped_Out'],
#       dtype='object')

# %%
df.Study_Time
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 644    3
# 645    2
# 646    2
# 647    1
# 648    1
# Name: Study_Time, Length: 649, dtype: int64

# %%
df
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0       GP      F   18       U         GT3               A                 4
# 1       GP      F   17       U         GT3               T                 1
# 2       GP      F   15       U         LE3               T                 1
# 3       GP      F   15       U         GT3               T                 4
# 4       GP      F   16       U         GT3               T                 3
# ..     ...    ...  ...     ...         ...             ...               ...
# 644     MS      F   19       R         GT3               T                 2
# 645     MS      F   18       U         LE3               T                 3
# 646     MS      F   18       U         GT3               T                 1
# 647     MS      M   17       U         LE3               T                 3
# 648     MS      M   18       R         LE3               T                 3
#
# ...

# %%
df[["Gender","Grade_1","Grade_2","Final_Grade","Dropped_Out"]]
# Out:
#     Gender  Grade_1  Grade_2  Final_Grade  Dropped_Out
# 0        F        0       11           11        False
# 1        F        9       11           11        False
# 2        F       12       13           12        False
# 3        F       14       14           14        False
# 4        F       11       13           13        False
# ..     ...      ...      ...          ...          ...
# 644      F       10       11           10        False
# 645      F       15       15           16        False
# 646      F       11       12            9         True
# 647      M       10       10           10        False
# 648      M       10       11           11        False
#
# [649 rows x 5 columns]

# %%
df[["Age","Gender","Final_Grade"]]
# Out:
#      Age Gender  Final_Grade
# 0     18      F           11
# 1     17      F           11
# 2     15      F           12
# 3     15      F           14
# 4     16      F           13
# ..   ...    ...          ...
# 644   19      F           10
# 645   18      F           16
# 646   18      F            9
# 647   17      M           10
# 648   18      M           11
#
# [649 rows x 3 columns]

# %%
df["Final_Grade"]
# Out:
# 0      11
# 1      11
# 2      12
# 3      14
# 4      13
#        ..
# 644    10
# 645    16
# 646     9
# 647    10
# 648    11
# Name: Final_Grade, Length: 649, dtype: int64

# %%
df["Final_Grade"].max()
# Out:
# 19

# %%
df["Final_Grade"].min()
# Out:
# 0

# %%
df['Number_of_Absences']
# Out:
# 0      4
# 1      2
# 2      6
# 3      0
# 4      0
#       ..
# 644    4
# 645    4
# 646    6
# 647    6
# 648    4
# Name: Number_of_Absences, Length: 649, dtype: int64

# %%
df['Number_of_Absences'].max()
# Out:
# 32

# %%
df['Number_of_Absences'].sum()
# Out:
# 2375

# %%
df[df.Final_Grade>=10]
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0       GP      F   18       U         GT3               A                 4
# 1       GP      F   17       U         GT3               T                 1
# 2       GP      F   15       U         LE3               T                 1
# 3       GP      F   15       U         GT3               T                 4
# 4       GP      F   16       U         GT3               T                 3
# ..     ...    ...  ...     ...         ...             ...               ...
# 643     MS      F   18       R         GT3               T                 4
# 644     MS      F   19       R         GT3               T                 2
# 645     MS      F   18       U         LE3               T                 3
# 647     MS      M   17       U         LE3               T                 3
# 648     MS      M   18       R         LE3               T                 3
#
# ...

# %%
df[df.Final_Grade<=9]
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 18      GP      M   17       U         GT3               T                 3
# 52      GP      M   15       U         LE3               A                 4
# 81      GP      M   15       U         GT3               T                 2
# 100     GP      M   16       U         GT3               T                 4
# 125     GP      M   15       U         GT3               T                 3
# ..     ...    ...  ...     ...         ...             ...               ...
# 635     MS      F   17       R         GT3               T                 3
# 637     MS      M   18       R         GT3               T                 2
# 639     MS      M   19       R         GT3               T                 1
# 640     MS      M   18       R         GT3               T                 4
# 646     MS      F   18       U         GT3               T                 1
#
# ...

# %%
df.describe()
# Out:
#               Age  Mother_Education  Father_Education  Travel_Time  \
# count  649.000000        649.000000        649.000000   649.000000
# mean    16.744222          2.514638          2.306626     1.568567
# std      1.218138          1.134552          1.099931     0.748660
# min     15.000000          0.000000          0.000000     1.000000
# 25%     16.000000          2.000000          1.000000     1.000000
# 50%     17.000000          2.000000          2.000000     1.000000
# 75%     18.000000          4.000000          3.000000     2.000000
# max     22.000000          4.000000          4.000000     4.000000
#
#        Study_Time  Number_of_Failures  Family_Relationship   Free_Time  \
# count  649.000000          649.000000           649.000000  649.000000
# mean     1.930663            0.221880             3.930663    3.180277
# std      0.829510            0.593235             0.955717    1.051093
# min      1.000000            0.000000             1.000000    1.000000
# ...

# %%
df[df.Final_Grade==df["Final_Grade"].max()]
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 338     GP      F   17       R         LE3               T                 3
# 636     MS      M   18       U         GT3               T                 4
#
#      Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 338                 1   services      other  ...         1         2
# 636                 4    teacher    teacher  ...         2         4
#
#      Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  \
# 338                            1                            1              3
# 636                            1                            4              2
#
#     Number_of_Absences Grade_1 Grade_2 Final_Grade Dropped_Out
# 338                  0      18      19          19       False
# 636                  4      17      18          19       False
#
# [2 rows x 34 columns]

# %%
df[df.Final_Grade==df["Final_Grade"].min()]
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 163     GP      M   18       U         LE3               T                 1
# 440     MS      M   16       U         GT3               T                 1
# 519     MS      M   16       R         GT3               T                 2
# 563     MS      M   17       U         GT3               T                 2
# 567     MS      M   18       R         GT3               T                 3
# 583     MS      F   18       R         GT3               T                 2
# 586     MS      F   17       U         GT3               T                 4
# 597     MS      F   18       R         GT3               T                 2
# 603     MS      F   18       R         LE3               A                 4
# 605     MS      F   19       U         GT3               T                 1
# 610     MS      F   19       R         GT3               A                 1
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=649, step=1)

# %%
df.set_index('Final_Grade')
# Out:
#             School Gender  Age Address Family_Size Parental_Status  \
# Final_Grade
# 11              GP      F   18       U         GT3               A
# 11              GP      F   17       U         GT3               T
# 12              GP      F   15       U         LE3               T
# 14              GP      F   15       U         GT3               T
# 13              GP      F   16       U         GT3               T
# ...            ...    ...  ...     ...         ...             ...
# 10              MS      F   19       R         GT3               T
# 16              MS      F   18       U         LE3               T
# 9               MS      F   18       U         GT3               T
# 10              MS      M   17       U         LE3               T
# 11              MS      M   18       R         LE3               T
#
#              Mother_Education  Father_Education Mother_Job Father_Job  ...  \
# ...

# %%
df
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0       GP      F   18       U         GT3               A                 4
# 1       GP      F   17       U         GT3               T                 1
# 2       GP      F   15       U         LE3               T                 1
# 3       GP      F   15       U         GT3               T                 4
# 4       GP      F   16       U         GT3               T                 3
# ..     ...    ...  ...     ...         ...             ...               ...
# 644     MS      F   19       R         GT3               T                 2
# 645     MS      F   18       U         LE3               T                 3
# 646     MS      F   18       U         GT3               T                 1
# 647     MS      M   17       U         LE3               T                 3
# 648     MS      M   18       R         LE3               T                 3
#
# ...

# %%
df.dtypes
# Out:
# School                         object
# Gender                         object
# Age                             int64
# Address                        object
# Family_Size                    object
# Parental_Status                object
# Mother_Education                int64
# Father_Education                int64
# Mother_Job                     object
# Father_Job                     object
# Reason_for_Choosing_School     object
# Guardian                       object
# Travel_Time                     int64
# Study_Time                      int64
# Number_of_Failures              int64
# School_Support                 object
# Family_Support                 object
# Extra_Paid_Class               object
# Extra_Curricular_Activities    object
# Attended_Nursery               object
# Wants_Higher_Education         object
# Internet_Access                object
# In_Relationship                object
# Family_Relationship             int64
# Free_Time                       int64
# ...

# %%
df.Dropped_Out.describe()
# Out:
# count       649
# unique        2
# top       False
# freq        549
# Name: Dropped_Out, dtype: object

# %%
df.Dropped_Out.value_counts()
# Out:
# Dropped_Out
# False    549
# True     100
# Name: count, dtype: int64

# %%
pd.crosstab(df.Final_Grade,df.Dropped_Out)
# Out:
# Dropped_Out  False  True
# Final_Grade
# 0                0     15
# 1                0      1
# 5                0      1
# 6                0      3
# 7                0     10
# 8                0     35
# 9                0     35
# 10              97      0
# 11             104      0
# 12              72      0
# 13              82      0
# 14              63      0
# 15              49      0
# 16              36      0
# 17              29      0
# 18              15      0
# 19               2      0

# %%
df.Number_of_Failures.describe()
# Out:
# count    649.000000
# mean       0.221880
# std        0.593235
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000
# Name: Number_of_Failures, dtype: float64

# %%
df.Number_of_Failures.value_counts()
# Out:
# Number_of_Failures
# 0    549
# 1     70
# 2     16
# 3     14
# Name: count, dtype: int64

# %%
df.Number_of_Absences.value_counts()
# Out:
# Number_of_Absences
# 0     244
# 2     110
# 4      93
# 6      49
# 8      42
# 10     21
# 1      12
# 12     12
# 5      12
# 16     10
# 14      8
# 9       7
# 3       7
# 11      5
# 18      3
# 7       3
# 21      2
# 15      2
# 22      2
# 30      1
# 26      1
# 24      1
# 13      1
# 32      1
# Name: count, dtype: int64

# %%
df.Final_Grade.sort_values()
# Out:
# 586     0
# 567     0
# 610     0
# 163     0
# 603     0
#        ..
# 185    18
# 549    18
# 337    18
# 338    19
# 636    19
# Name: Final_Grade, Length: 649, dtype: int64

# %%
df.Final_Grade.value_counts()
# Out:
# Final_Grade
# 11    104
# 10     97
# 13     82
# 12     72
# 14     63
# 15     49
# 16     36
# 9      35
# 8      35
# 17     29
# 18     15
# 0      15
# 7      10
# 6       3
# 19      2
# 1       1
# 5       1
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
df.Final_Grade.plot(kind='hist')
plt.title('FINAL GRADE', c='ORANGE')
plt.xlabel('GRADE')
# Out:
# Text(0.5, 0, 'GRADE')

# %%
df.Dropped_Out.value_counts().plot(kind='bar')
plt.title('DROPPED OUT', c='red')
plt.ylabel('Number of dropped out')
# Out:
# Text(0, 0.5, 'Number of dropped out')

# %%
df.Gender.value_counts().plot(kind='bar')
plt.title('GENDER RECORD', c='green')
plt.ylabel('Number of Gender')
# Out:
# Text(0, 0.5, 'Number of Gender')
